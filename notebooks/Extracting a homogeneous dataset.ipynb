# %% [markdown]
# # Extracting a homogeneous dataset

# %%
# %matplotlib inline
from PDBClean import homogenutils as homogen

# %%
colab=False
if colab:
    RUNDIR='./'
else:
    RUNDIR='../examples/'
PROJDIR=RUNDIR+'AKproject'

# %%
atommap, keychain = homogen.process(projdir=PROJDIR, mode='show_atommap', source='final_bank', dry_run=True)

# %%
new_atommap, new_keychain = homogen.maximize_samplesize(atommap, keychain)
homogen.show_atommap(new_atommap)

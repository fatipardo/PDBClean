# %% [markdown]
# # Extracting a homogeneous dataset

# %%
colab=False
local_relative_path='../examples/'
project_name='AKproject'

# %%
# %matplotlib inline
from PDBClean import pdbclean_io as pcio
from PDBClean import pdbclean_process as pcx

# %%
RUNDIR  = pcio.define_rundir(local_relative_path, colab=colab)
PROJDIR = RUNDIR+project_name
pcio.check_project(projdir=PROJDIR, action='create', level='ca_homogopt_bank')
# Out:
# ../examples/AKproject/ca_homogopt_bank already exists, with content:
# ['info.txt', '2ar7+06.cif', '2ar7+07.cif', '2bbw+01.cif', '2bbw+02.cif', '5x6k+01.cif', '5x6k+02.cif', '5x6l+01.cif', '5x6l+02.cif', '5xru+01.cif', '5xru+02.cif', '5ycb+01.cif', '5ycb+02.cif', '5ycc+01.cif', '5ycc+02.cif']

# %%
pcx.process(projdir=PROJDIR, source='sel_bank', target='ca_homogopt_bank',
            verbose=True, show=True,
            step='homogenize', mode='optimize')
# Out:
# {'mode': 'optimize'}
# Building keychain from all files. Length of keychain:
# 226<221<221<221<226<226<227<227<227<227<230<230<230<230<3
# Building atom map from keychain.
# Setting up and solving Binary linear program.
# G.shape = (12880, 3464)
# h.shape = (12880,)
# w.shape = (3464,)
# Solution is optimal. Score went from 2743.0 to 2520. We keep 14 / 14 samples and 180 / 230 features.
# Building atom map from keychain.
# [1/14]: ../examples/AKproject/ca_homogopt_bank/2ar7+06.cif
# [2/14]: ../examples/AKproject/ca_homogopt_bank/2ar7+07.cif
# [3/14]: ../examples/AKproject/ca_homogopt_bank/2bbw+01.cif
# [4/14]: ../examples/AKproject/ca_homogopt_bank/2bbw+02.cif
# [5/14]: ../examples/AKproject/ca_homogopt_bank/5x6k+01.cif
# [6/14]: ../examples/AKproject/ca_homogopt_bank/5x6k+02.cif
# [7/14]: ../examples/AKproject/ca_homogopt_bank/5x6l+01.cif
# [8/14]: ../examples/AKproject/ca_homogopt_bank/5x6l+02.cif
# [9/14]: ../examples/AKproject/ca_homogopt_bank/5xru+01.cif
# [10/14]: ../examples/AKproject/ca_homogopt_bank/5xru+02.cif
# [11/14]: ../examples/AKproject/ca_homogopt_bank/5ycb+01.cif
# [12/14]: ../examples/AKproject/ca_homogopt_bank/5ycb+02.cif
# [13/14]: ../examples/AKproject/ca_homogopt_bank/5ycc+01.cif
# [14/14]: ../examples/AKproject/ca_homogopt_bank/5ycc+02.cif

# %% [markdown]
# # Extracting a homogeneous dataset

# %%
colab=False
if colab:
    RUNDIR='./'
else:
    RUNDIR='../examples/'

# %%
# %matplotlib inline
from PDBClean import pdbclean_io
from PDBClean import homogenutils as homogen

# %%
PROJDIR=RUNDIR+'AKproject'
pdbclean_io.check_project(projdir=PROJDIR, action='create', level='homogmax_bank')
# Out:
# ../examples/AKproject/homogmax_bank already exists, with content:
# ['info.txt', '2ar7+06.cif']

# %%
homogen.process(projdir=PROJDIR, mode='keep_all_samples', source='final_bank', target='homogmax_bank', verbose=True, show=True)
# Out:
# Building keychain from all files. Length of keychain:
# 1881<1933<2000<2005<2344<2344<2349<2349<2349<2349<2374<2374<2379<2379<3
# Building atom map from keychain.
# Building atom map from keychain.
# [1/14]: ../examples/AKproject/homogmax_bank/2ar7+06.cif
# [2/14]: ../examples/AKproject/homogmax_bank/2ar7+07.cif
# [3/14]: ../examples/AKproject/homogmax_bank/2bbw+01.cif
# [4/14]: ../examples/AKproject/homogmax_bank/2bbw+02.cif
# [5/14]: ../examples/AKproject/homogmax_bank/5x6k+01.cif
# [6/14]: ../examples/AKproject/homogmax_bank/5x6k+02.cif
# [7/14]: ../examples/AKproject/homogmax_bank/5x6l+01.cif
# [8/14]: ../examples/AKproject/homogmax_bank/5x6l+02.cif
# [9/14]: ../examples/AKproject/homogmax_bank/5xru+01.cif
# [10/14]: ../examples/AKproject/homogmax_bank/5xru+02.cif
# [11/14]: ../examples/AKproject/homogmax_bank/5ycb+01.cif
# [12/14]: ../examples/AKproject/homogmax_bank/5ycb+02.cif
# [13/14]: ../examples/AKproject/homogmax_bank/5ycc+01.cif
# ...

# %%
dic1 = {}
dic1['a'] = ['1','2', '3']
mask = [True, False, True]
import itertools
dic1['a'] = list(itertools.compress(dic1['a'], mask))
print(dic1['a'])
